# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from bs4 import BeautifulSoup
from selenium.webdriver.chrome.service import Service
from selenium import webdriver

service = Service(executable_path='/Users/igormiroshnykov/Downloads/chromedriver')
driver = webdriver.Chrome(service=service)

# %%
sats = 'https://www.google.com/travel/explore?tfs=CBwQAxoqagwIAhIIL20vMGQ2bHASCjIwMjItMDctMTZyDAgEEggvbS8wM2doNCgAGipqDAgEEggvbS8wM2doNBIKMjAyMi0wNy0yM3IMCAISCC9tLzBkNmxwKABwAYIBCwj___________8BQAFIAZgBAbIBBBgBIAE&tfu=GgA'

# %%
driver.get(sats)

# %%
driver.title
# Out:
# 'San Francisco to Hawaii | Explore'

# %%
driver.save_screenshot('/Users/igormiroshnykov/Documents/GitHub/Orion/Python/Machine Learning/test_flights.png')
# Out:
# True

# %%
soup = BeautifulSoup(driver.page_source, "html5lib")
#tsAU4E

# %%
soup
# Out:
# <html dir="ltr" lang="en"><head><style nonce="">.gm-control-active>img{box-sizing:content-box;display:none;left:50%;pointer-events:none;position:absolute;top:50%;transform:translate(-50%,-50%)}.gm-control-active>img:nth-child(1){display:block}.gm-control-active:focus>img:nth-child(1),.gm-control-active:hover>img:nth-child(1),.gm-control-active:active>img:nth-child(1),.gm-control-active:disabled>img:nth-child(1){display:none}.gm-control-active:focus>img:nth-child(2),.gm-control-active:hover>img:nth-child(2){display:block}.gm-control-active:active>img:nth-child(3){display:block}.gm-control-active:disabled>img:nth-child(4){display:block}
# ...

# %%
cards = soup.select('div[class*=tsAU4e]')

cards[0]
# Out:
# <div class="tsAU4e"><div class="wIuJz"><h3 class="W6bZuc YMlIz">Honolulu</h3><div class="ZjDced CQYfx"><img alt="United" class="GDcknf C5fbBf" data-iml="12652.099999964237" src="https://www.gstatic.com/flights/airline_logos/70px/UA.png"/><span class="nx0jzf">Nonstop</span><span aria-label=" " class="qeoz6e U325Rc"></span><span class="Xq1DAb">5 hr 24 min</span></div></div><div class="Q70fcd sSHqwe"><div class="MJg7fb"><span class="QB2Jof xLPuCe"><span aria-label="658 US dollars" data-gs="CjRIUjNtWHVMVnNLYjRBQzZFUndCRy0tLS0tLS0tLXBmdjE0M0FBQUFBR0t5SDNnTlRFaEFBEgEyGgsIrIEEEAIaA1VTRDgpcKyBBA==" role="text">$658</span></span></div></div></div>

# %%
for card in cards:
    print(card.select ('h3')[0].text)
    print(card.select('span[class*=QB2Jof]')[0].text)
    print('\n')
# Out:
# Honolulu
# $658
#
#
# Kauai
# $632
#
#
# Kailua-Kona
# $544
#
#
# Hilo
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-28-3a9d376f7a05> in <module>
#       1 for card in cards:
#       2     print(card.select ('h3')[0].text)
# ----> 3     print(card.select('span[class*=QB2Jof]')[0].text)
#       4     print('\n')
#
# IndexError: list index out of range

# %%
print(cards.select('span[class*=QB2Jof]'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-0e1458a7e59a> in <module>
# ----> 1 print(cards.select('span[class*=QB2Jof]'))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/bs4/element.py in __getattr__(self, key)
#    2171     def __getattr__(self, key):
#    2172         """Raise a helpful exception to explain a common code fix."""
# -> 2173         raise AttributeError(
#    2174             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2175         )
#
# AttributeError: ResultSet object has no attribute 'select'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
